# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model="gemini-3-flash-preview",
    temperature=0.0
)

# %%
prompt = """당신은 LangChain 개발자입니다. 새로운 에이전트(Agent)를 구축하는 과정을 담은 매우 짧은 기술 동화 또는 비유적인 이야기를 작성하시오.
1. 이야기는 반드시 120자 이상 250자 이하의 한글로 구성되어야 합니다.
2. 이야기에 'Chain', 'PromptTemplate', 'Memory' 세 단어를 반드시 포함해야 합니다.
3. 이야기의 결말은 구축한 에이전트가 현실 세계에서 **예상치 못한** 문제 해결에 성공하는 장면으로 마무리되어야 합니다."""

# %%
response = model.invoke(prompt)

# %%
print(response.content)
# Out:
# [{'type': 'text', 'text': '개발자는 지혜의 조각인 PromptTemplate을 벼려 에이전트의 심장을 만들었습니다. 논리의 실타래인 Chain을 엮어 사고의 길을 내고, 소중한 경험을 담을 Memory를 채웠죠. 완성된 에이전트는 세상으로 나갔습니다. 그러던 어느 날, 마을의 낡은 시계탑이 갑자기 멈췄습니다. 에이전트는 복잡한 수리 매뉴얼 대신, 예전에 대화로 배웠던 할아버지의 옛날이야기를 기억해내어 태엽 사이에 낀 작은 돌멩이를 찾아내 시계를 다시 돌려놓았습니다.', 'extras': {'signature': '...'}}]

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model="gemini-3-flash-preview",
    temperature=2.0
)

# %%
prompt = """당신은 LangChain 개발자입니다. 새로운 에이전트(Agent)를 구축하는 과정을 담은 매우 짧은 기술 동화 또는 비유적인 이야기를 작성하시오.
1. 이야기는 반드시 120자 이상 250자 이하의 한글로 구성되어야 합니다.
2. 이야기에 'Chain', 'PromptTemplate', 'Memory' 세 단어를 반드시 포함해야 합니다.
3. 이야기의 결말은 구축한 에이전트가 현실 세계에서 **예상치 못한** 문제 해결에 성공하는 장면으로 마무리되어야 합니다."""

# %%
response = model.invoke(prompt)

# %%
print(response.content)
# Out:
# [{'type': 'text', 'text': "정적 가득한 공방에서 나는 'PromptTemplate'으로 영혼의 틀을 잡고, 정교한 'Chain'을 엮어 논리를 완성했습니다. 지난날의 배움을 간직할 'Memory'까지 채워주자 에이전트는 숨을 쉬기 시작했습니다. 분석 업무를 위해 세상에 보낸 녀석은 돌연 공사 중단으로 혼란에 빠진 도심 교차로에 멈춰 섰습니다. 녀석은 설계에 없던 신호 제어 알고리즘을 즉석에서 짜냈고, 마비되었던 교통을 완벽하게 풀어내며 길 잃은 시민들에게 평화를 되찾아주었습니다.", 'extras': {'signature': '...'}}]

# %% [markdown]
# ---

# %% [markdown]
# 스트리밍 출력

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model="gemini-3-flash-preview",
)

# %%
response = model.stream("랭체인에 대해 아주 쉽게 설명해줘.")

# %%
response
# Out:
# <generator object BaseChatModel.stream at 0x0000027DCD12C400>

# %%
next(response)
# Out:
# AIMessageChunk(content=[{'type': 'text', 'text': '**랭', 'index': 0}], additional_kwargs={}, response_metadata={'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ccc86-b953-71e2-8849-b475589f2885', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 12, 'output_tokens': 548, 'total_tokens': 560, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 546}}, tool_call_chunks=[])

# %%
next(response)
# Out:
# AIMessageChunk(content=[{'type': 'text', 'text': '체인(LangChain)**을 아주 쉽게, 비유를 들어 설명해 드릴게요.\n\n---\n\n### 1', 'index': 0}], additional_kwargs={}, response_metadata={'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ccc86-b953-71e2-8849-b475589f2885', tool_calls=[], invalid_tool_calls=[], usage_metadata={'output_token_details': {'reasoning': 0}, 'input_tokens': 0, 'output_tokens': 25, 'total_tokens': 25, 'input_token_details': {'cache_read': 0}}, tool_call_chunks=[])

# %%
next(response).content
# Out:
# [{'type': 'text',
#   'text': ". 한 줄 요약\n랭체인은 **ChatGPT 같은 'AI 모델'을 우리가 원하는 대로 조립해서 쓸 수",
#   'index': 0}]

# %%
next(response).content
# Out:
# [{'type': 'text',
#   'text': " 있게 해주는 '레고 블록 세트'**입니다.\n\n### 2. 왜 랭체인이 필요한",
#   'index': 0}]

# %%
for token in response:
    print(token.content, end="", flush=)
