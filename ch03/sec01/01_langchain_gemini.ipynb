# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model="gemini-3-flash-preview",
    temperature=1.0,  # Gemini 3.0+ defaults to 1.0
    max_tokens=None,
    timeout=None,
    max_retries=2,
    # other params...
)

# %%
messages = [
    (
        "system",
        "You are a helpful assistant that translates English to Korean. Translate the user sentence.",
    ),
    ("human", "I love programming."),
]
ai_msg = model.invoke(messages)
ai_msg
# Out:
# AIMessage(content=[{'type': 'text', 'text': '저는 프로그래밍을 좋아해요.', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3-flash-preview', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ccc5f-2e15-7230-8485-17949a3c166d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 21, 'output_tokens': 441, 'total_tokens': 462, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 433}})

# %% [markdown]
# 멀티 모달 테스트

# %%
from langchain.messages import HumanMessage
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-3-flash-preview")

message = HumanMessage(
    content=[
        {"type": "text", "text": "Describe the image at the URL. 한국어로 답하시오."},
        {
            "type": "image",
            "url": "https://picsum.photos/seed/picsum/200/300",
        },
    ]
)
response = model.invoke([message])

# %%
response.text
# Out:
# '이 이미지는 해가 뜨거나 질 무렵의 고요하고 아름다운 설산 풍경을 담고 있습니다.\n\n* **하늘:** 이미지의 윗부분은 부드러운 분홍색, 주황색, 옅은 보라색으로 물든 구름이 가득 채우고 있어 따뜻하면서도 신비로운 분위기를 자아냅니다.\n* **산봉우리:** 오른쪽에는 눈이 쌓인 험준하고 가파른 산봉우리가 솟아 있습니다. 봉우리의 꼭대기 부분에는 구름이나 눈 가루가 바람에 흩날리는 듯한 모습이 포착되었습니다.\n* **전경:** 왼쪽 하단에는 어두운 푸른색 그림자가 드리워진 매끄러운 눈 언덕이 산봉우리와 대조를 이루며 평온한 느낌을 더해줍니다.\n\n전체적으로 차가운 눈의 질감과 따뜻한 색감의 하늘이 어우러져 장엄하고 평화로운 대자연의 모습을 보여줍니다.'
