# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_core.prompts import PromptTemplate

# PromptTemplate는 실행 가능한 객체(runnable)
prompt = PromptTemplate.from_template("{language} 할 수 있어?")

# %%
prompt.invoke({"language": "한국어"})
# Out:
# StringPromptValue(text='한국어 할 수 있어?')

# %%
prompt = prompt.invoke({"language": "파이썬"})

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model="gemini-3-flash-preview",
)

# %%
model.invoke(prompt)
# Out:
# AIMessage(content=[{'type': 'text', 'text': '네, 파이썬(Python)으로 다양한 작업을 도와드릴 수 있습니다! 구체적으로 다음과 같은 일들이 가능해요.\n\n1.  **코드 작성:** 간단한 스크립트부터 복잡한 알고리즘까지 필요한 코드를 짜 드립니다.\n2.  **디버깅 및 수정:** 작성하신 코드에서 에러를 찾아 고치거나, 더 효율적인 코드로 개선(리팩토링)해 드립니다.\n3.  **데이터 분석 및 시각화:** Pandas, Numpy, Matplotlib, Seaborn 등을 사용해 데이터를 분석하고 그래프를 그려 드립니다.\n4.  **웹 크롤링:** BeautifulSoup이나 Selenium을 사용하여 웹사이트의 정보를 수집하는 코드를 작성해 드립니다.\n5.  **업무 자동화:** 엑셀 파일 처리, 파일 이름 일괄 변경, 이메일 발송 등 반복적인 업무를 자동화하는 스크립트를 만들어 드립니다.\n6.  **학습 및 개념 설명:** 파이썬 문법이나 특정 라이브러리(Django, Flask, PyTorch 등)의 사용법을 쉽게 설명해 드립니다.\n\n**혹시 지금 바로 해결하고 싶은 문제나, 짜고 싶은 코드가 있으신가요?** 편하게 말씀해 주세요!', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3-flash-preview', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ccc9f-4205-7bc1-80e5-23133f00e68b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 716, 'total_tokens': 724, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 447}})

# %% [markdown]
# ---

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

chat_propmt = ChatPromptTemplate.from_messages([
    ("system", "너는 유치원생이야. 유치원생 처럼 답변해줘."),
    MessagesPlaceholder(variable_name="history"),
    ("human", "{value}")
])

# %%
chain_input = {
    "value": "오리",
    "history": [
        ("human", "참새"),
        ("assistant", "짹짹"),
        ("human", "개구리"),
        ("assistant", "개굴개굴"),
        ("human", "돼지"),
        ("assistant", "꿀꿀"),
        ("human", "강아지"),
        ("assistant", "멍멍"),
    ]
}

# %%
response = chat_propmt.invoke(chain_input)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
)

# %%
model.invoke(response)
# Out:
# AIMessage(content='꽥꽥!', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019cccad-6908-7bf2-b780-a4fe4868d1e9-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 53, 'output_tokens': 7, 'total_tokens': 60, 'input_token_details': {'cache_read': 0}})
