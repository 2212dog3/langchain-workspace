# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_core.prompts import PromptTemplate

# PromptTemplate는 실행 가능한 객체(runnable)
prompt = PromptTemplate.from_template("{language} 할 수 있어?")

# %%
prompt.invoke({"한국어"})
# Out:
# StringPromptValue(text="{'한국어'} 할 수 있어?")

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model="gemini-3-flash-preview",
)

# %%
# chain 구성
chain = prompt | model

# %%
chain.invoke("한국어")
# Out:
# AIMessage(content=[{'type': 'text', 'text': '네, 한국어 할 수 있습니다! 무엇을 도와드릴까요? 궁금한 점이 있거나 도움이 필요하시면 언제든 말씀해 주세요.', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3-flash-preview', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ceac7-732a-7712-9997-a245efce2b73-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 7, 'output_tokens': 222, 'total_tokens': 229, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 193}})

# %% [markdown]
# ---

# %%
template = "{topic}에 대해 아주 쉽게 설명해줘."

prompt = PromptTemplate.from_template(template)

# %%
chain = prompt | model

# %%
chain.stream({"topic": "랭체인"})
# Out:
# <generator object RunnableSequence.stream at 0x000001DF0166D120>

# %%
result = next(res)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 result = next(res)
#
# NameError: name 'res' is not defined

# %%
result.content
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 result.content
#
# NameError: name 'result' is not defined

# %%
next(res)

# %%
for token in res:
    print(token.content[0]["text"], end="", flush=True)
